# %%
def reddit_link(row):
    return f"https://reddit.com/{row['reddit_id']}"

# %%
import sys
sys.path
sys.path.append('/home/sapristi/dev/fleebmarket/advert_parsing/')

# %%
from pydantic import BaseModel, validator
import pandas as pd
import more_itertools
from enum import Enum
from typing import Optional
import re
import ipywidgets as ipw
from collections import defaultdict
from dataclasses import dataclass

from advert_parsing.markdown_parser import Text, Heading, Listing, Table,  Paragraph, md_to_ast
from advert_parsing.table_classification import extract_tables, combined_classif

# %%
try:
    data_full = pd.read_pickle('adverts_parsed.pickle')
except FileNotFoundError:
    data_full = pd.read_csv('adverts.csv').drop_duplicates(subset=['full_text'], keep='last')
    data_full['ast'] = data_full['full_text'].apply(md_to_ast)
    data_full.to_pickle('adverts_parsed.pickle')
    
data_full['ast']
# Out:
# 0       children=[Paragraph(children=[Text(text='GMK D...
# 1       children=[Paragraph(children=[Text(text='Hello...
# 2       children=[Paragraph(children=[Text(text='Times...
# 3       children=[Paragraph(children=[Text(text='Times...
# 4       children=[Paragraph(children=[Text(text='TIMES...
#                               ...
# 9995    children=[Paragraph(children=[Text(text='Times...
# 9996    children=[Paragraph(children=[Text(text='Times...
# 9997    children=[Paragraph(children=[Text(text='Howdy...
# 9998    children=[Paragraph(children=[Text(text='Times...
# 9999    children=[Paragraph(children=[Text(text='times...
# Name: ast, Length: 9899, dtype: object

# %%
data_full['tables'] = data_full['ast'].apply(extract_tables)
data_full['tables_df'] = data_full['tables'].apply(lambda l: [pd.DataFrame(item.rows) for item in l])
data_full['tables_df'].iloc[0][0]
# Out:
#                                                     0  \
# 0                           text='Price' styles=set()
# 1                          text='30 Eur' styles=set()
# 2   children=[Text(text='280 Eur', styles={<StyleV...
# 3                         text='115 Eur' styles=set()
# 4              text='10 Eur/each keycap' styles=set()
# 5                          text='70 Eur' styles=set()
# 6                          text='16 Eur' styles=set()
# 7                          text='35 Eur' styles=set()
# 8                          text='30 Eur' styles=set()
# 9                          text='20 Eur' styles=set()
# 10                         text='35 Eur' styles=set()
# 11                         text='16 Eur' styles=set()
# 12                     text='1 Eur each' styles=set()
# 13                         text='30 Eur' styles=set()
# 14                         text='25 Eur' styles=set()
#
#                                                     1
# 0                            text='Item' styles=set()
# 1   text='Cherry G81-3000 new keyboard ISO-UK Desc...
# 2   text='GMK Oblivion V2 Git base + split spaceba...
# 3   text="GMK DMG 60% arrows layout keys Descripti...
# 4   text='GMK Novelties keys Description: New cond...
# 5   text='GMK Esc keys collection Description: New...
# 6   text='GMK MX logo keys kit Description: New' s...
# 7   text='GMK Geekhack logo kit Description: New' ...
# 8   text='Hot Keys Project 6u Topre Caution Bar De...
# 9   text="Hector's cable Beige sleeve UsbC Descrip...
# 10  text='GMK TA 90 (Triumph Adler) Spacebars kit ...
# 11  text='16 switches acrylic switch tester Descri...
# 12  text='Various novelty keys Description: Random...
# 13  text='GMK Blue Red Green Yellow modifiers Desc...
# 14  text='Clear rasin + gold foil hammer and sickl...

# %%
total_tables = sum(map(len, data_full['tables_df']))
total_tables
# Out:
# 3323

# %%
tables_array = [
    table 
    for tables in data_full['tables_df']
    for table in tables
]
len(tables_array)
# Out:
# 3323

# %%
classif_df = pd.DataFrame(tables_array, columns=['table'])
classif_df['classif'] = classif_df['table'].apply(combined_classif)
# Out:
# /home/sapristi/.virtualenvs/advert_parsing/lib/python3.10/site-packages/pandas/core/internals/construction.py:540: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   values = np.array([convert(v) for v in values])

# %%
from advert_parsing.table_classification import classify_with_header, make_bool_df, classify_table_simple, ItemsTable, Failure, ArtisanTable, NotRelevant
from advert_parsing.classification_utils.prices import  find_sold_token_in_text, find_prices_in_text, find_price_wo_curr_in_text
def combined_classif_py310(df):
    header_classif = classify_with_header(df)
    sold_bool_df = make_bool_df(df, find_sold_token_in_text)

    price_classif = classify_table_simple(df, find_prices_in_text)
    if not isinstance(price_classif, ItemsTable):
        price_classif_wocurr = classify_table_simple(df, find_price_wo_curr_in_text)
        if isinstance(price_classif_wocurr, ItemsTable):
            price_classif = price_classif_wocurr

    match header_classif, price_classif:
        case ItemsTable(price_cols=price_cols_1, has_header=_), ItemsTable(price_cols=price_cols_2):
            common_cols = set(price_cols_1) & set(price_cols_2)
            if len(common_cols) == 0:
                return Failure(reason="No common col between header and price classif")
            return ItemsTable(price_cols=common_cols, has_header=True)
        
        case ItemsTable(price_cols=price_cols, has_header=_), Failure(reason=_):
            return ItemsTable(price_cols=price_cols, has_header=True)
        
        case ItemsTable(price_cols=price_cols, has_header=_), ArtisanTable() | NotRelevant():
            return Failure(reason="different_classif")
        
        case Failure(reason=_), ItemsTable(price_cols=price_cols):
            return ItemsTable(price_cols=price_cols, has_header=False)
            
        case Failure(reason=_), _:
            return price_classif
        
        case _, _:
            print(header_classif, price_classif)
            raise

# %%
classif_df['classif_py310'] = classif_df['table'].apply(combined_classif_py310)

# %%
classif_df[classif_df['classif'] != classif_df['classif_py310']]
# Out:
#                                                   table  \
# 37                                                  ...
# 256                                                 ...
# 295                                                 ...
# 410                          0                      ...
# 446                                             0   ...
# 531                                                 ...
# 619                                               0 ...
# 648                                     0           ...
# 729                                                 ...
# 778                                                 ...
# 828                                     0           ...
# 881         0     1     2                           ...
# 983                                                 ...
# 1010                         0                      ...
# 1056                         0                      ...
# 1200                                                ...
# 1339                                                ...
# 1369                         0                      ...
# 1588                                              0 ...
# 1646                         0                      ...
# 1785                                            0   ...
# 1851                                                ...
# 1916                                                ...
# 2189                                                ...
# 2385                                                ...
# 2477                         0                      ...
# 2529                                                ...
# 2582                                                ...
# 2643                         0                      ...
# 2681                                                ...
# 2848                         0                      ...
# 3035                         0                      ...
# 3157                                                ...
#
#                                    classif  \
# 37       price_cols=[1, 2] has_header=None
# 256      price_cols=[2, 1] has_header=None
# 295      price_cols=[0, 2] has_header=None
# 410      price_cols=[1, 2] has_header=None
# 446      price_cols=[2, 1] has_header=None
# 531      price_cols=[0, 2] has_header=None
# 619   price_cols=[4, 2, 3] has_header=None
# 648      price_cols=[0, 4] has_header=None
# 729      price_cols=[0, 2] has_header=None
# 778      price_cols=[1, 2] has_header=None
# 828      price_cols=[0, 4] has_header=None
# 881      price_cols=[3, 4] has_header=None
# 983      price_cols=[0, 1] has_header=None
# 1010     price_cols=[1, 2] has_header=None
# 1056     price_cols=[1, 2] has_header=None
# 1200     price_cols=[1, 2] has_header=None
# 1339     price_cols=[0, 2] has_header=None
# 1369     price_cols=[1, 2] has_header=None
# 1588     price_cols=[1, 2] has_header=None
# 1646     price_cols=[3, 6] has_header=None
# 1785     price_cols=[2, 1] has_header=None
# 1851     price_cols=[0, 1] has_header=None
# 1916     price_cols=[1, 2] has_header=None
# 2189     price_cols=[0, 2] has_header=None
# 2385     price_cols=[1, 2] has_header=None
# 2477     price_cols=[3, 4] has_header=None
# 2529     price_cols=[1, 2] has_header=None
# 2582     price_cols=[0, 2] has_header=None
# 2643     price_cols=[1, 2] has_header=None
# 2681     price_cols=[0, 2] has_header=None
# 2848     price_cols=[1, 2] has_header=None
# 3035     price_cols=[1, 2] has_header=None
# 3157     price_cols=[0, 2] has_header=None
#
#                               classif_py310
# 37       price_cols=[1, 2] has_header=False
# 256      price_cols=[2, 1] has_header=False
# 295      price_cols=[0, 2] has_header=False
# 410      price_cols=[1, 2] has_header=False
# 446      price_cols=[2, 1] has_header=False
# 531      price_cols=[0, 2] has_header=False
# 619   price_cols=[4, 2, 3] has_header=False
# 648      price_cols=[0, 4] has_header=False
# 729      price_cols=[0, 2] has_header=False
# 778      price_cols=[1, 2] has_header=False
# 828      price_cols=[0, 4] has_header=False
# 881      price_cols=[3, 4] has_header=False
# 983      price_cols=[0, 1] has_header=False
# 1010     price_cols=[1, 2] has_header=False
# 1056     price_cols=[1, 2] has_header=False
# 1200     price_cols=[1, 2] has_header=False
# 1339     price_cols=[0, 2] has_header=False
# 1369     price_cols=[1, 2] has_header=False
# 1588     price_cols=[1, 2] has_header=False
# 1646     price_cols=[3, 6] has_header=False
# 1785     price_cols=[2, 1] has_header=False
# 1851     price_cols=[0, 1] has_header=False
# 1916     price_cols=[1, 2] has_header=False
# 2189     price_cols=[0, 2] has_header=False
# 2385     price_cols=[1, 2] has_header=False
# 2477     price_cols=[3, 4] has_header=False
# 2529     price_cols=[1, 2] has_header=False
# 2582     price_cols=[0, 2] has_header=False
# 2643     price_cols=[1, 2] has_header=False
# 2681     price_cols=[0, 2] has_header=False
# 2848     price_cols=[1, 2] has_header=False
# 3035     price_cols=[1, 2] has_header=False
# 3157     price_cols=[0, 2] has_header=False

# %%
classif_df['class'] = classif_df['classif'].apply(lambda o: o.__class__.__name__)

# %%
classif_df.groupby(['class']).count()
